# %%
### Copy of Main.py as a juypter notebook to visualize results

###
### 0. Import packages and references
###
### - dataSeed = seed for simulations or (for csv input) for randomization of csv

exec(open('C:/dev/NeuronalNetworkTensorflowFramework/src/NNFramework/packages.py').read())
dataSeed = 1 
weightSeed = 1 


###
### 1. Training data
###

# 10^4 data data points
randomized = True 
generator = DataImporter('C:/dev/NeuronalNetworkTensorflowFramework/src/Examples/CumulativeDensitiyFunction/1. CDF unrandomized/cdf_deterministic_data.csv','x','CDF(x)',randomized = randomized,testDataPath='C:/dev/NeuronalNetworkTensorflowFramework/src/Examples/CumulativeDensitiyFunction/1. CDF unrandomized/cdf_deterministic_data.csv') 
sizes = [100,1000,10000] # training set sizes. Performed one after the other and might be compared
nTest = None # Test set is given through a ratio of 0.8 in generator


###
### 2. Set Nueral network structure / Hyperparameters
### 

hiddenNeurons = 20               # we use equal neurons for each hidden layer
hiddenLayers = 2                # amount of hidden layers
activationFunctions = tf.nn.tanh    # activation functions of hidden layers

epochs = 50
###
### 3. Train network
###
trainingMethod = TrainingMethod.Standard

xTest, yTest, yPredicted = train_and_test(generator, sizes, nTest, dataSeed, None, weightSeed, hiddenNeurons, hiddenLayers, activationFunctions, trainingMethod, epochs = epochs)
    
###
### 3. Study results
###   

# show predicitions
plot_results("CDF unrandomized deterministic inputs", yPredicted, xTest, "x", "CDF(x)", yTest, sizes, True, False, None, trainingMethod)
# Out:
# TF version = 2.10.0
# TF version = 2.10.0
# TF version = 2.10.0
# TF version = 2.10.0
# simulating training, valid and test sets
# done
# initializing neural appropximator
# done
#
# size 100
# Neural network initialized with the following settings:
# Neurons per layer: 20
# Amount of hidden layers: 2
# Activations functions: <function tanh at 0x0000021C7D10FEE0>
# Training will be done with the following settings:
#
# min_batch_size: 20
# batches per epoch: 10
# Hence, used batch_size will be: 20
# epochs: 50
# learning_rate_schedule: [(0.0, 0.01), (0.2, 0.001), (0.4, 0.0001), (0.6, 1e-05), (0.8, 1e-06)]
#
#  Train started:
# RMSE on training data after 5 epochs is 0.06505915888942534. RMSE on test data: 0.06515642464360653
# RMSE on training data after 10 epochs is 0.054632163680015465. RMSE on test data: 0.05487331221156209
# RMSE on training data after 15 epochs is 0.05115891823593116. RMSE on test data: 0.05142950249258479
# RMSE on training data after 20 epochs is 0.049056604370674314. RMSE on test data: 0.049333404109356736
# RMSE on training data after 25 epochs is 0.0486773196905213. RMSE on test data: 0.0489559570171576
# RMSE on training data after 30 epochs is 0.0485084974745565. RMSE on test data: 0.048788016996268384
# RMSE on training data after 35 epochs is 0.04846999895296343. RMSE on test data: 0.048749728180840106
# RMSE on training data after 40 epochs is 0.0484519300481003. RMSE on test data: 0.04873175385439369
# RMSE on training data after 45 epochs is 0.04844678798370776. RMSE on test data: 0.04872663414306698
# RMSE on training data after 50 epochs is 0.0484414990642576. RMSE on test data: 0.04872136981278795
# Training done.
#
# size 1000
# Neural network initialized with the following settings:
# Neurons per layer: 20
# Amount of hidden layers: 2
# Activations functions: <function tanh at 0x0000021C7D10FEE0>
# Training will be done with the following settings:
#
# min_batch_size: 20
# batches per epoch: 10
# Hence, used batch_size will be: 100
# epochs: 50
# learning_rate_schedule: [(0.0, 0.01), (0.2, 0.001), (0.4, 0.0001), (0.6, 1e-05), (0.8, 1e-06)]
#
#  Train started:
# RMSE on training data after 5 epochs is 0.04764554857290276. RMSE on test data: 0.047644675979080946
# RMSE on training data after 10 epochs is 0.00778355119989768. RMSE on test data: 0.0078015788361907815
# RMSE on training data after 15 epochs is 0.0067875374778766425. RMSE on test data: 0.006653214636311987
# RMSE on training data after 20 epochs is 0.006293824584699862. RMSE on test data: 0.006202973952723436
# RMSE on training data after 25 epochs is 0.006255887141335591. RMSE on test data: 0.006145815976218777
# RMSE on training data after 30 epochs is 0.006228166407749902. RMSE on test data: 0.006118468378492304
# RMSE on training data after 35 epochs is 0.00622294546605781. RMSE on test data: 0.00611322521231811
# RMSE on training data after 40 epochs is 0.006220127803869029. RMSE on test data: 0.00611039640324438
# RMSE on training data after 45 epochs is 0.006219334731820181. RMSE on test data: 0.006109613702792709
# RMSE on training data after 50 epochs is 0.006218424002145135. RMSE on test data: 0.0061087468895945655
# Training done.
#
# size 10000
# Neural network initialized with the following settings:
# Neurons per layer: 20
# Amount of hidden layers: 2
# Activations functions: <function tanh at 0x0000021C7D10FEE0>
# Training will be done with the following settings:
#
# min_batch_size: 20
# batches per epoch: 10
# Hence, used batch_size will be: 1000
# epochs: 50
# learning_rate_schedule: [(0.0, 0.01), (0.2, 0.001), (0.4, 0.0001), (0.6, 1e-05), (0.8, 1e-06)]
#
#  Train started:
# RMSE on training data after 5 epochs is 0.03644304803323003. RMSE on test data: 0.0363769974342402
# RMSE on training data after 10 epochs is 0.007195939645843008. RMSE on test data: 0.0070245438507627045
# RMSE on training data after 15 epochs is 0.0056337460771410134. RMSE on test data: 0.005516335546476111
# RMSE on training data after 20 epochs is 0.005314179182581964. RMSE on test data: 0.005205466981022995
# RMSE on training data after 25 epochs is 0.005243113939267346. RMSE on test data: 0.0051312138781435465
# RMSE on training data after 30 epochs is 0.005210398233019932. RMSE on test data: 0.005098807384926851
# RMSE on training data after 35 epochs is 0.0052031924551906505. RMSE on test data: 0.005091560458708434
# RMSE on training data after 40 epochs is 0.005199983594233877. RMSE on test data: 0.0050882728154640405
# RMSE on training data after 45 epochs is 0.005199063896159006. RMSE on test data: 0.005087326328876556
# RMSE on training data after 50 epochs is 0.005198138607220353. RMSE on test data: 0.005086373937753177
# Training done.
