# %%
### Copy of Main.py as a juypter notebook to visualize results

###
### 0. Import packages and references
###
### - dataSeed = seed for simulations or (for csv input) for randomization of csv

exec(open('C:/dev/NeuronalNetworkTensorflowFramework/src/NNFramework/packages.py').read())
dataSeed = 1 
weightSeed = 1 


###
### 1. Training data
###

# 10^4 data data points
randomized = False 
generator = DataImporter('C:/dev/NeuronalNetworkTensorflowFramework/src/Examples/CumulativeDensitiyFunction/3. CDF_MC/cdf_randomInputs_data.csv','x','CDF(x)',randomized = randomized,testDataPath='C:/dev/NeuronalNetworkTensorflowFramework/src/Examples/CumulativeDensitiyFunction/3. CDF_MC/cdf_randomInputs_data.csv') 
sizes = [100,1000,10000] # training set sizes. Performed one after the other and might be compared
nTest = None # Test set is given through a ratio of 0.8 in generator


###
### 2. Set Nueral network structure / Hyperparameters
### 

hiddenNeurons = 20               # we use equal neurons for each hidden layer
hiddenLayers = 2                # amount of hidden layers
activationFunctions = tf.nn.tanh    # activation functions of hidden layers

epochs = 50
###
### 3. Train network
###
trainingMethod = TrainingMethod.Standard

xTest, yTest, yPredicted = train_and_test(generator, sizes, nTest, dataSeed, None, weightSeed, hiddenNeurons, hiddenLayers, activationFunctions, trainingMethod, epochs = epochs)
    
###
### 3. Study results
###   

# show predicitions
plot_results("CDF unrandomized deterministic inputs", yPredicted, xTest, "x", "CDF(x)", yTest, sizes, True, False, None, trainingMethod)
# Out:
# TF version = 2.10.0
# TF version = 2.10.0
# TF version = 2.10.0
# TF version = 2.10.0
# simulating training, valid and test sets
# done
# initializing neural appropximator
# done
#
# size 100
# Neural network initialized with the following settings:
# Neurons per layer: 20
# Amount of hidden layers: 2
# Activations functions: <function tanh at 0x000001FD7F0FFEE0>
# Training will be done with the following settings:
#
# min_batch_size: 20
# batches per epoch: 10
# Hence, used batch_size will be: 20
# epochs: 50
# learning_rate_schedule: [(0.0, 0.01), (0.2, 0.001), (0.4, 0.0001), (0.6, 1e-05), (0.8, 1e-06)]
#
#  Train started:
# RMSE on training data after 5 epochs is 0.06298997279968399. RMSE on test data: 0.06239250713734229
# RMSE on training data after 10 epochs is 0.04907793654880366. RMSE on test data: 0.04973873761259473
# RMSE on training data after 15 epochs is 0.046030542621314195. RMSE on test data: 0.046747416460126624
# RMSE on training data after 20 epochs is 0.04439013344197538. RMSE on test data: 0.0451372731081343
# RMSE on training data after 25 epochs is 0.04390621555341936. RMSE on test data: 0.0446218965157756
# RMSE on training data after 30 epochs is 0.04375070038177498. RMSE on test data: 0.04447724032293246
# RMSE on training data after 35 epochs is 0.043705039978407155. RMSE on test data: 0.04443059755763955
# RMSE on training data after 40 epochs is 0.043685468705872706. RMSE on test data: 0.04441078260662833
# RMSE on training data after 45 epochs is 0.04368000867471828. RMSE on test data: 0.04440520971242836
# RMSE on training data after 50 epochs is 0.04367435095778868. RMSE on test data: 0.04439938551015127
# Training done.
#
# size 1000
# Neural network initialized with the following settings:
# Neurons per layer: 20
# Amount of hidden layers: 2
# Activations functions: <function tanh at 0x000001FD7F0FFEE0>
# Training will be done with the following settings:
#
# min_batch_size: 20
# batches per epoch: 10
# Hence, used batch_size will be: 100
# epochs: 50
# learning_rate_schedule: [(0.0, 0.01), (0.2, 0.001), (0.4, 0.0001), (0.6, 1e-05), (0.8, 1e-06)]
#
#  Train started:
# RMSE on training data after 5 epochs is 0.04338628238789515. RMSE on test data: 0.04408760247578666
# RMSE on training data after 10 epochs is 0.00741479695779147. RMSE on test data: 0.0073489381490894744
# RMSE on training data after 15 epochs is 0.006249841485087095. RMSE on test data: 0.006264746455266416
# RMSE on training data after 20 epochs is 0.006004676753009465. RMSE on test data: 0.006064078178427975
# RMSE on training data after 25 epochs is 0.005943105831082734. RMSE on test data: 0.00599078836143956
# RMSE on training data after 30 epochs is 0.005911878430123396. RMSE on test data: 0.005955225933678496
# RMSE on training data after 35 epochs is 0.005904964031671043. RMSE on test data: 0.005947842731712214
# RMSE on training data after 40 epochs is 0.005901796228925247. RMSE on test data: 0.005944623771949691
# RMSE on training data after 45 epochs is 0.005900938610895066. RMSE on test data: 0.005943757869902853
# RMSE on training data after 50 epochs is 0.005900055501637663. RMSE on test data: 0.005942838993126805
# Training done.
#
# size 10000
# Neural network initialized with the following settings:
# Neurons per layer: 20
# Amount of hidden layers: 2
# Activations functions: <function tanh at 0x000001FD7F0FFEE0>
# Training will be done with the following settings:
#
# min_batch_size: 20
# batches per epoch: 10
# Hence, used batch_size will be: 1000
# epochs: 50
# learning_rate_schedule: [(0.0, 0.01), (0.2, 0.001), (0.4, 0.0001), (0.6, 1e-05), (0.8, 1e-06)]
#
#  Train started:
# RMSE on training data after 5 epochs is 0.04176158961278012. RMSE on test data: 0.041766195303823875
# RMSE on training data after 10 epochs is 0.009227343509300141. RMSE on test data: 0.009611244241271893
# RMSE on training data after 15 epochs is 0.0056628329614383105. RMSE on test data: 0.005829286069312219
# RMSE on training data after 20 epochs is 0.005421399280406194. RMSE on test data: 0.005577311489047234
# RMSE on training data after 25 epochs is 0.005362104489555402. RMSE on test data: 0.005506071193071016
# RMSE on training data after 30 epochs is 0.0053346217001094785. RMSE on test data: 0.005474437929186859
# RMSE on training data after 35 epochs is 0.0053280678348333515. RMSE on test data: 0.0054666934234166254
# RMSE on training data after 40 epochs is 0.0053250225269568735. RMSE on test data: 0.005463155297881639
# RMSE on training data after 45 epochs is 0.005324138640349742. RMSE on test data: 0.0054621232650906406
# RMSE on training data after 50 epochs is 0.005323266113859311. RMSE on test data: 0.005461123573159023
# Training done.
